# %% [markdown]
# ## Python DataTypes
#
# #### There are different types of python data types. Some built-in python data types are:
#
# #### - Numbers
# #### - Strings
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Python Data Type-Numeric
#
# #### * Python numeric data type is used to hold numeric values like;
#    #### - int-  holds signed integers of non-limited length.
#    #### - long- holds long integers(exists in Python 2.x, deprecated in Python 3.x).
#    #### - float- holds floating precision numbers and it’s accurate upto 15 decimal places.
#    #### - complex- holds complex  numbers.
# #### * In Python we need not to declare data type while declaring a variable like C or C++.
# #### * We can simply just assign values in a variable. But if we want to see what type of numerical value is it holding right now, we can use type(), like this

# %% [markdown]
# ### Integer - holds signed integers of non-limited length.

# %%
num = 13423432434242342432442
print(num)
print(type(num))

num1 = input("Enter interger numbers::: ")
print(num1)
# Out:
# 13423432434242342432442
# <class 'int'>
# 3423423424234324234234

# %% [markdown]
# ### long - holds long integers(exists in Python 2.x, deprecated in Python 3.x) below code will explain which version of python we are using so long keyword is no longer available.

# %%
import sys
print(sys.version)
# Out:
# 3.11.8 (v3.11.8:db85d51d3e, Feb  6 2024, 18:02:37) [Clang 13.0.0 (clang-1300.0.29.30)]

# %% [markdown]
# ### float- holds floating precision numbers and it’s accurate upto 15 decimal places.

# %%
float_num = 10.234567898123456
print(float_num)
print(type(float_num))

float_num1 = input("Enter a float number::: ")
print(float_num1)
# Out:
# 10.234567898123457
# <class 'float'>
# 12.35

# %% [markdown]
# ### complex- holds complex  numbers.

# %%
complex_num = 10+3j
print(complex_num)
print(type(complex_num))

print(complex_num.imag)
print(complex_num.real)
# Out:
# (10+3j)
# <class 'complex'>
# 3.0
# 10.0

# %% [markdown]
# ### Python Data Type-String
#
# #### * String is a sequence of characters. Python supports Unicode characters.
# #### * Generally strings are represented by either single or doublequotes.

# %%
single_quote = 'python is in single quote'
double_quote = "python is in double quote"

print(single_quote)
print(double_quote)

# concate string 

print(single_quote + " " +double_quote)
print(single_quote,double_quote)
# Out:
# python is in single quote
# python is in double quote
# python is in single quote python is in double quote
# python is in single quote python is in double quote

# %% [markdown]
# ### What is String  in Python?
# #### - A string is a sequence of characters.
# #### - A character is simply a symbol. For example, the English language has 26 characters.
# #### - Computers do not deal with characters, they deal with numbers (binary). Eventhough you may see characters on your screen, internally it is stored and manipulated as a combination of 0's and 1's.
# #### - This conversion of character to a number is called encoding, and the reverse process is decoding. ASCI and Unicode are some of the popular encoding used.
# #### - In Python, string is a sequence of Unicode character. Unicode was introduced to  include every character in all languages and bring uniformity in encoding.

# %% [markdown]
# ### How to create a string in Python?
#
# #### Strings can be created by enclosing characters inside a single quote or double quotes. Even  triple quotes can be used in Python but generally used to represent multiline  strings and  doc strings.

# %%
single_quote = 'string in single quote'
print(single_quote)

double_quote = "String in double quote"
print(double_quote)

triple_quote = """
String in triple quote and we can using triple quote in doc string and paragraph
"""

print(triple_quote)
# Out:
# string in single quote
# String in double quote
#
# String in triple quote and we can using triple quote in doc string and paragraph

# %% [markdown]
# ### How to access characters in a string?
#
# #### - We can access individual characters using indexing and a range of characters using slicing. Index starts from 0. Trying to access a  character out of index range will raise an IndexError. The index must be an integer. We can't use float or other types, this will result  into TypeError.
# #### - Python allows negative indexing for its sequences.
# #### - The index of -1 refers to the last item, -2 to the second last item and soon. We can access arrange of items in a string by  using the slicing operator (colon).

# %%
name = "Muralidharan"

#first character 
print(name[0])

#last character 
print(name[-1])

#group of characters
print(name[0:5])
print(name[:])
print(name[5:-9])
# Out:
# M
# n
# Mural
# Muralidharan

# %% [markdown]
# #### We cannot use decimal point and out of the index values so can get the ValueError, IndexError

# %% [markdown]
# ### How to change or delete astring?
#
# #### Strings are immutable. This means that elements of a string cannot be  changed once it has been assigned. We can simply reassign different strings  to the same name.
# ### makes Python very flexible in assigning data types; it differs from other languages that are statically typed.
#  ```python
# my_string="welcome"
# my_string="Hello"
# ```
# #### We cannot delete or remove characters from a string. But deleting the  string entirely is possible using the keyword del.

# %%
my_string = "Welcome"
my_string="hello"
print(my_string)

# del my_string[0] deleting single string is not possbile and get TypeError: 'str' object doesn't support item deletion
# deleting complete string is possbile by using del keyword.

del my_string
# print(my_string)
# Out:
# hello

# %% [markdown]
# ### *What is immutable and mutable?*
#
# ### *Mutable objects:*
#
# #### - Mutable objects can be changed after they are created.
# #### - Examples of mutable objects in Python include lists, dictionaries, sets, and instances of most user-defined classes.
# #### - When you modify a mutable object, the object itself is actually being changed.
#
# ##### Example of a mutable object (list)
#  ```python
# my_list = [1, 2, 3]
# my_list.append(4)  # Modifying the list
# print(my_list)  # Output: [1, 2, 3, 4]
#    ```
#
# ### *Immutable objects:*
#
# #### - Immutable objects cannot be changed once they are created.
# #### - Examples of immutable objects in Python include integers, floats, strings, tuples, and frozensets.
# #### - When you attempt to modify an immutable object, a new object is actually created with the new value.
#
# #### Example of an immutable object (string)
#  ```python
# my_string = "Hello"
# my_string = my_string + " World"  # Creating a new string
# print(my_string)  # Output: "Hello World"
# ```
#
# ![image.png](attachment:image.png)

# %%
# String in built methods

name = "Muralidharan"

# String capitalize() Method
print(name.capitalize())

# String center() Method
print(name.center(20))

#String count() Method 
print(name.count('a'))

# String isupper() Method
print(name.isupper())

# String islower() Method
print(name.islower())

#String upper() Method
print(name.upper())

#String lower() Method
print(name.lower())

# String title() Method
print(name.title())

# String spilt() Method
print(name.split(' '))
# Out:
# Muralidharan
#     Muralidharan
# 3
# False
# False
# MURALIDHARAN
# muralidharan
# Muralidharan
# ['Muralidharan']

# %% [markdown]
# #####  *Author - Muralidharan Venkadesan*
#
# ##### *LinkedIn profile - https://www.linkedin.com/in/muralidharanvenkadesan/*
