# %% [markdown]
# ## Python Complete Notes
#
# Pandas is a powerful and popular open-source data manipulation and analysis library for Python. It is widely used for data science, data analysis, and machine learning tasks due to its ease of use and ability to handle large datasets efficiently. Here are some key features and functionalities of Pandas:
#
# ### 1. Data Structures
# Pandas primarily provides two data structures for manipulating data:
#
# - **Series**: A one-dimensional labeled array capable of holding any data type. Think of it as a column in a table.
# - **DataFrame**: A two-dimensional labeled data structure with columns that can be of different types. It is similar to a table in a database or an Excel spreadsheet.
#
# ### 2. Data Handling
# Pandas offers robust functions to handle and manipulate data, including:
#
# - **Data Loading**: Import data from various file formats such as CSV, Excel, SQL databases, JSON, HTML, and more.
# - **Data Cleaning**: Handle missing data, remove duplicates, and perform various transformations.
# - **Data Merging**: Combine data from multiple sources using joins, concatenation, and merging techniques.
# - **Data Aggregation**: Group data and perform aggregate operations like sum, mean, count, etc.
#
# ### 3. Data Analysis
# Pandas makes it easy to perform complex data analysis tasks:
#
# - **Descriptive Statistics**: Quickly generate summary statistics for your data.
# - **Time Series Analysis**: Efficiently handle and manipulate time series data.
# - **Data Visualization**: Easily plot data using integrated plotting functions that work well with Matplotlib.
#
# ### 4. Indexing and Selection
# Pandas provides powerful tools for data selection and subsetting:
#
# - **Label-based Indexing**: Access data using labels (row and column names).
# - **Position-based Indexing**: Access data using integer location-based indexing.
# - **Boolean Indexing**: Filter data based on conditions.
#
# ### 5. Performance
# Pandas is designed for performance and can handle large datasets efficiently:
#
# - **Optimized Operations**: Many operations are implemented in C or Cython for speed.
# - **Memory Efficiency**: Efficient handling of data in memory to minimize usage.
#
# ### Example Usage
# Here is a simple example to illustrate the usage of Pandas:
#
# ```python
# import pandas as pd
#
# # Create a DataFrame
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie'],
#     'Age': [25, 30, 35],
#     'City': ['New York', 'Los Angeles', 'Chicago']
# }
# df = pd.DataFrame(data)
#
# # Display the DataFrame
# print(df)
#
# # Calculate the average age
# average_age = df['Age'].mean()
# print(f'Average Age: {average_age}')
#
# # Filter data
# filtered_df = df[df['Age'] > 30]
# print(filtered_df)
# ```
#
# In this example, we create a DataFrame, display it, calculate the average age, and filter rows based on a condition.
#
# Pandas is a versatile and essential tool in the data scientist's toolkit, making data manipulation and analysis both easy and efficient.

# %% [markdown]
# ## Intro to Dataframes

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
df.head()
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"])
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"], index=["X","Y","Z"])
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.tail(2)
# Out:
#    A  B  C
# Y  4  5  6
# Z  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
df.index.to_list()
# Out:
# ['X', 'Y', 'Z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %% [markdown]
# ## Loading in Dataframes from Files

# %%
## Load the CSV file

coffee = pd.read_csv('warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
result = pd.read_parquet('data/results.parquet')

# %%
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
result1 = pd.read_feather('data/results.feather')

# %%
result1.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
result2 = pd.read_excel('data/olympics-data.xlsx')

# %%
result2.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(6)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
coffee.tail(7)
# Out:
#          Day Coffee Type  Units Sold
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(10) # Pass in random_state to make deterministic
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 12     Sunday    Espresso          45
# 10   Saturday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 7    Thursday       Latte          30
# 1      Monday       Latte          15
# 5   Wednesday       Latte          25

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[0:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee.loc[0:]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[:5]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
coffee.loc[5:12,["Day", "Coffee Type"]]
# Out:
#           Day Coffee Type
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso

# %%
coffee.iloc[0:8,[0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30

# %%
coffee.loc[1,"Units Sold"] = 20

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          20
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[1:3,"Units Sold"] = 10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
coffee.at[0,"Units Sold"]
# Out:
# np.int64(25)

# %%
coffee.iat[0,0]
# Out:
# 'Monday'

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 13     Sunday       Latte          35
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values("Units Sold", ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[1,0])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10
# 2     Tuesday    Espresso          10
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print("\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
#
#
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
#
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
#
#
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
#
#
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object

# %%
bios = pd.read_csv('data/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios['height_cm'] > 215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# 6722          6755       Shaquille O'Neal  1972-03-06                  Newark
# 6937          6972         David Robinson  1965-08-06                Key West
# 6978          7013        Arvydas Sabonis  1964-12-19                  Kaunas
# 7074          7111         Paulo da Silva  1963-07-21               São Paulo
# 7188          7226     Vladimir Tkachenko  1957-09-20               Golovinka
# 7281          7320       Stojko Vranković  1964-01-22                   Drniš
# 7376          7416    Eurelijus Žukauskas  1973-08-22                Klaipėda
# 52608        52983        Aleksey Kazakov  1976-03-18      Naberezhnye Chelny
# 82100        82753          Frédéric Weis  1977-06-22              Thionville
# 89070        89782               Yao Ming  1980-09-12          Xuhui District
# 89075        89787         Roberto Dueñas  1975-11-01                  Madrid
# 107408      108533       Peter John Ramos  1985-05-23                 Fajardo
# 112312      113568           Stanko Barać  1986-08-13                  Mostar
# 112332      113588    Andreas Glyniadakis  1981-08-26                  Chania
# 112337      113593          Hamed Haddadi  1985-05-19                   Ahvaz
# 118663      120400         Timofey Mozgov  1986-07-16                     NaN
# 118676      120415        Dmitry Musersky  1988-10-29                Makiïvka
# 120266      122147           Zhang Zhaoxu  1987-11-18                 Binzhou
# 121694      123709            Salah Mejri  1986-06-15                Jendouba
# 123850      126093         Tyson Chandler  1982-10-02                 Hanford
# 130460      133147               Li Muhao  1992-06-02                 Guiyang
# 130461      133148                Zhou Qi  1996-01-16                Xinxiang
# 138671      142084          Ondřej Balvín  1992-09-20          Ústí nad Labem
# 139365      142836         Moustapha Fall  1992-02-23                   Paris
#
#                             born_region born_country  \
# 5089                             Moskva          RUS
# 5583                          São Paulo          BRA
# 5673                Nordrhein-Westfalen          GER
# 5716                             Bayern          GER
# 5781                     North Carolina          USA
# 5796                           Victoria          AUS
# 6223                        Hovedstaden          DEN
# 6270                                NaN          NaN
# 6409                                NaN          NaN
# 6420                        Cēsu novads          LAT
# 6504                           Victoria          AUS
# 6722                         New Jersey          USA
# 6937                            Florida          USA
# 6978                             Kaunas          LTU
# 7074                          São Paulo          BRA
# 7188                     Krasnodar Kray          RUS
# 7281          Šibensko-kninska županija          CRO
# 7376                           Klaipėda          LTU
# 52608              Respublika Tatarstan          RUS
# 82100                           Moselle          FRA
# 89070                          Shanghai          CHN
# 89075                            Madrid          ESP
# 107408                      Puerto Rico          PUR
# 112312  Hercegovačko-neretvanski kanton          BIH
# 112332                            Kriti          GRE
# 112337                        Khuzestan          IRI
# 118663                              NaN          NaN
# 118676                          Donetsk          UKR
# 120266                         Shandong          CHN
# 121694                         Jendouba          TUN
# 123850                       California          USA
# 130460                          Guizhou          CHN
# 130461                            Henan          CHN
# 138671                     Ústecký kraj          CZE
# 139365                            Paris          FRA
#
#                                NOC  height_cm  weight_kg   died_date
# 5089                  Soviet Union      220.0      112.0  1993-07-24
# 5583                        Brazil      217.0      106.0         NaN
# 5673                       Germany      221.0      114.0         NaN
# 5716          Germany West Germany      218.0      110.0         NaN
# 5781                 United States      223.0      102.0         NaN
# 5796                     Australia      218.0       93.0         NaN
# 6223                        Canada      216.0      105.0         NaN
# 6270    People's Republic of China      216.0      135.0         NaN
# 6409                  Soviet Union      216.0      111.0  2004-11-18
# 6420                  Soviet Union      218.0      141.0  1994-11-20
# 6504                     Australia      220.0      135.0         NaN
# 6722                 United States      216.0      137.0         NaN
# 6937                 United States      216.0      107.0         NaN
# 6978        Lithuania Soviet Union      223.0      122.0         NaN
# 7074                        Brazil      217.0      106.0         NaN
# 7188                  Soviet Union      220.0      110.0         NaN
# 7281            Croatia Yugoslavia      217.0      115.0         NaN
# 7376                     Lithuania      218.0      115.0         NaN
# 52608           Russian Federation      217.0      102.0         NaN
# 82100                       France      218.0      110.0         NaN
# 89070   People's Republic of China      226.0      141.0         NaN
# 89075                        Spain      221.0      137.0         NaN
# 107408                 Puerto Rico      219.0      113.0         NaN
# 112312                     Croatia      217.0      110.0         NaN
# 112332                      Greece      216.0      115.0         NaN
# 112337    Islamic Republic of Iran      218.0      110.0         NaN
# 118663          Russian Federation      216.0      113.0         NaN
# 118676          Russian Federation      219.0      104.0         NaN
# 120266  People's Republic of China      221.0      110.0         NaN
# 121694                     Tunisia      216.0      110.0         NaN
# 123850               United States      216.0      107.0         NaN
# 130460  People's Republic of China      218.0      115.0         NaN
# 130461  People's Republic of China      217.0       95.0         NaN
# 138671                     Czechia      216.0      107.0         NaN
# 139365                      France      218.0        NaN         NaN

# %%
bios.loc[bios['height_cm'] > 215, ["name","height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
bios.loc[bios['height_cm'] > 215][["name","height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
bios.loc[(bios["height_cm"] > 215) & (bios['born_country'] == "USA")]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains("Tommy",case=False)]
# Out:
#         athlete_id               name   born_date          born_city  \
# 2134          2144        Tommy Quick  1955-07-22             Skövde
# 2768          2780        Tommy Reidy  1968-11-26                NaN
# 3452          3464     Tommy Nicholls  1931-10-12      South Elmsall
# 3463          3475       Tommy Pardoe  1911-04-14         Birmingham
# 3468          3480     Tommy Proffitt  1927-07-13                NaN
# ...            ...                ...         ...                ...
# 131601      134409     Tommy Sugiarto  1988-05-31            Jakarta
# 134652      137741  Tommy Kristiansen  1989-05-26          Sarpsborg
# 139669      143146    Tommy Fleetwood  1991-01-19          Southport
# 143141      146773       Tommy Macias  1993-01-20                Boo
# 143828      147484         Tommy Paul  1997-05-17  Voorhees Township
#
#                           born_region born_country            NOC  height_cm  \
# 2134                  Västra Götaland          SWE         Sweden      175.0
# 2768                              NaN          NaN  United States      183.0
# 3452                          England          GBR  Great Britain        NaN
# 3463                          England          GBR  Great Britain      164.0
# 3468                              NaN          NaN  Great Britain        NaN
# ...                               ...          ...            ...        ...
# 131601  Daerah Khusus Ibukota Jakarta          INA      Indonesia      175.0
# 134652                          Viken          NOR         Norway      189.0
# 139669                        England          GBR  Great Britain      178.0
# 143141                      Stockholm          SWE         Sweden        NaN
# 143828                     New Jersey          USA  United States      185.0
#
#         weight_kg   died_date
# 2134         60.0  2013-11-10
# 2768         68.0         NaN
# 3452          NaN  2021-07-31
# 3463          NaN  1992-12-07
# 3468          NaN  2023-03-23
# ...           ...         ...
# 131601       71.0         NaN
# 134652       99.0         NaN
# 139669        NaN         NaN
# 143141        NaN         NaN
# 143828        NaN         NaN
#
# [99 rows x 10 columns]

# %%
bios[bios['name'].str.contains("Tommy | David",case=False)]
# Out:
#         athlete_id             name   born_date          born_city  \
# 2134          2144      Tommy Quick  1955-07-22             Skövde
# 2768          2780      Tommy Reidy  1968-11-26                NaN
# 3452          3464   Tommy Nicholls  1931-10-12      South Elmsall
# 3463          3475     Tommy Pardoe  1911-04-14         Birmingham
# 3468          3480   Tommy Proffitt  1927-07-13                NaN
# ...            ...              ...         ...                ...
# 142845      146473    Selvyn Davids  1994-03-26                NaN
# 142848      146476      Zaïn Davids  1997-05-04                NaN
# 143141      146773     Tommy Macias  1993-01-20                Boo
# 143533      147186  Tierna Davidson  1998-09-19         Menlo Park
# 143828      147484       Tommy Paul  1997-05-17  Voorhees Township
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 2134    Västra Götaland          SWE         Sweden      175.0       60.0
# 2768                NaN          NaN  United States      183.0       68.0
# 3452            England          GBR  Great Britain        NaN        NaN
# 3463            England          GBR  Great Britain      164.0        NaN
# 3468                NaN          NaN  Great Britain        NaN        NaN
# ...                 ...          ...            ...        ...        ...
# 142845              NaN          NaN   South Africa        NaN        NaN
# 142848              NaN          NaN   South Africa        NaN        NaN
# 143141        Stockholm          SWE         Sweden        NaN        NaN
# 143533       California          USA  United States      178.0        NaN
# 143828       New Jersey          USA  United States      185.0        NaN
#
#          died_date
# 2134    2013-11-10
# 2768           NaN
# 3452    2021-07-31
# 3463    1992-12-07
# 3468    2023-03-23
# ...            ...
# 142845         NaN
# 142848         NaN
# 143141         NaN
# 143533         NaN
# 143828         NaN
#
# [156 rows x 10 columns]

# %%
bios[bios['name'].str.contains("Tommy | David",case=False, regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
# Other cool regex filters

# Find athletes born in cities that start with a vowel:
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]

# Find athletes with names that contain exactly two vowels:
two_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]

# Find athletes with names that have repeated consecutive letters (e.g., "Aaron", "Emmett"):
repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]

# Find athletes with names ending in 'son' or 'sen':
son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]

# Find athletes born in a year starting with '19':
born_19xx = bios[bios['born_date'].str.contains(r'^19', na=False)]

# Find athletes with names that do not contain any vowels:
no_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*$', na=False)]

# Find athletes whose names contain a hyphen or an apostrophe:
hyphen_apostrophe = bios[bios['name'].str.contains(r"[-']", na=False)]

# Find athletes with names that start and end with the same letter:
start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]

# Find athletes with a born_city that has exactly 7 characters:
city_seven_chars = bios[bios['born_city'].str.contains(r'^.{7}$', na=False)]

# Find athletes with names containing three or more vowels:
three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]
# Out:
# /var/folders/qj/948gfl_s7ps7l_t1pwg1clpc0000gn/T/ipykernel_74422/1632287501.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]
# /var/folders/qj/948gfl_s7ps7l_t1pwg1clpc0000gn/T/ipykernel_74422/1632287501.py:25: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]
# /var/folders/qj/948gfl_s7ps7l_t1pwg1clpc0000gn/T/ipykernel_74422/1632287501.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]

# %%
bios[bios["born_country"].isin(["USA","SWE","GBR"]) & (bios["name"].str.startswith("Tommy"))]
# Out:
#         athlete_id              name   born_date          born_city  \
# 2134          2144       Tommy Quick  1955-07-22             Skövde
# 3452          3464    Tommy Nicholls  1931-10-12      South Elmsall
# 3463          3475      Tommy Pardoe  1911-04-14         Birmingham
# 5781          5804    Tommy Burleson  1952-02-24          Crossnore
# 6348          6379      Tommy Keenan  1923-05-19            Glasgow
# 8673          8720        Tommy Lown  1904-04-05           New York
# 10715        10771       Tommy Karls  1961-10-13           Nyköping
# 14582        14679      Tommy Harvey  1888-07-03        Westminster
# 16094        16206        Tommy Prim  1955-07-29         Svenljunga
# 18110        18231   Tommy Hitchcock  1900-02-11              Aiken
# 20839        20986      Tommy Angell  1924-05-06           Berkeley
# 25028        25218      Tommy Farrer  1922-12-22          Hoddesdon
# 25103        25293    Tommy Thompson  1938-03-09   Stockton-on-Tees
# 33784        34046      Tommy Martin  1956-08-25           Stockton
# 33835        34098   Tommy Mortensen  1966-01-04         Simrishamn
# 34184        34449   Tommy Tegelgård  1948-10-24           Huddinge
# 44397        44738        Tommy Pool  1935-02-10              Bowie
# 46985        47335      Tommy Mather  1908-08-15             London
# 54331        54722   Tommy Danielson  1949-06-25          Stockholm
# 56592        56995        Tommy Kono  1930-06-27         Sacramento
# 60189        60621       Tommy Evans  1931-01-21              Tulsa
# 65767        66264        Tommy Town  1893-04-07          Greenwich
# 68445        68962      Tommy Clarke  1882-11-13           Harmston
# 68574        69091       Tommy Green  1894-03-30            Fareham
# 68590        69107     Tommy Hammond  1878-06-18            Hitcham
# 68591        69108     Tommy Hampson  1907-10-28            Clapham
# 77943        78534      Tommy Haynes  1952-07-14          Nashville
# 84127        84796      Tommy Clarke  1911-11-19          Liverpool
# 89821        90539      Tommy Mulkey  1972-10-16            Atlanta
# 93106        93854      Tommy Hannan  1980-01-14          Baltimore
# 94749        95516         Tommy Moe  1970-02-17           Missoula
# 94933        95700       Tommy Mörth  1959-07-16          Stockholm
# 96180        96955        Tommy Ross  1927-09-01            Glasgow
# 96329        97105        Tommy Salo  1971-02-01         Surahammar
# 96357        97134  Tommy Samuelsson  1960-01-12          Degerfors
# 96808        97586      Tommy Sjödin  1965-08-13              Timrå
# 97304        98090  Tommy Söderström  1969-07-17          Stockholm
# 99906       100707     Tommy Albelin  1964-05-21          Stockholm
# 100267      101116    Tommy Czeschin  1979-06-15      Mammoth Lakes
# 100585      101435     Tommy Schwall  1983-08-01  Steamboat Springs
# 117035      118481        Tommy Ford  1989-03-20            Hanover
# 117534      119036    Tommy Eliasson  1980-02-28              Boden
# 123997      126258       Tommy Smith  1990-03-31       Macclesfield
# 139669      143146   Tommy Fleetwood  1991-01-19          Southport
# 143141      146773      Tommy Macias  1993-01-20                Boo
# 143828      147484        Tommy Paul  1997-05-17  Voorhees Township
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 2134    Västra Götaland          SWE         Sweden      175.0       60.0
# 3452            England          GBR  Great Britain        NaN        NaN
# 3463            England          GBR  Great Britain      164.0        NaN
# 5781     North Carolina          USA  United States      223.0      102.0
# 6348           Scotland          GBR        Ireland        NaN        NaN
# 8673           New York          USA  United States        NaN        NaN
# 10715      Södermanland          SWE         Sweden      181.0       85.0
# 14582           England          GBR  Great Britain        NaN        NaN
# 16094   Västra Götaland          SWE         Sweden      185.0       76.0
# 18110    South Carolina          USA  United States      178.0        NaN
# 20839        California          USA  United States      158.0       59.0
# 25028           England          GBR  Great Britain        NaN        NaN
# 25103           England          GBR  Great Britain      173.0       67.0
# 33784        California          USA  United States      179.0       93.0
# 33835             Skåne          SWE        Denmark      174.0       65.0
# 34184         Stockholm          SWE         Sweden      180.0       75.0
# 44397             Texas          USA  United States      188.0      105.0
# 46985           England          GBR  Great Britain        NaN        NaN
# 54331         Stockholm          SWE         Sweden      193.0       93.0
# 56592        California          USA  United States      167.0        NaN
# 60189          Oklahoma          USA  United States      167.0       67.0
# 65767           England          GBR         Canada      173.0        NaN
# 68445           England          GBR  Great Britain        NaN        NaN
# 68574           England          GBR  Great Britain        NaN        NaN
# 68590           England          GBR  Great Britain        NaN        NaN
# 68591           England          GBR  Great Britain      184.0       69.0
# 77943         Tennessee          USA  United States      177.0       75.0
# 84127           England          GBR  Great Britain        NaN        NaN
# 89821           Georgia          USA  United States      185.0       81.0
# 93106          Maryland          USA  United States      188.0       91.0
# 94749           Montana          USA  United States      178.0       89.0
# 94933         Stockholm          SWE         Sweden      178.0       87.0
# 96180          Scotland          GBR  Great Britain      171.0       70.0
# 96329       Västmanland          SWE         Sweden      181.0       79.0
# 96357            Örebro          SWE         Sweden      174.0       74.0
# 96808    Västernorrland          SWE         Sweden      182.0       89.0
# 97304         Stockholm          SWE         Sweden      175.0       66.0
# 99906         Stockholm          SWE         Sweden      186.0       87.0
# 100267       California          USA  United States      175.0       66.0
# 100585         Colorado          USA  United States      183.0       64.0
# 117035    New Hampshire          USA  United States      180.0       75.0
# 117534       Norrbotten          SWE         Sweden      179.0       90.0
# 123997          England          GBR    New Zealand      187.0       82.0
# 139669          England          GBR  Great Britain      178.0        NaN
# 143141        Stockholm          SWE         Sweden        NaN        NaN
# 143828       New Jersey          USA  United States      185.0        NaN
#
#          died_date
# 2134    2013-11-10
# 3452    2021-07-31
# 3463    1992-12-07
# 5781           NaN
# 6348    1981-04-07
# 8673    1977-09-22
# 10715          NaN
# 14582   1965-03-20
# 16094          NaN
# 18110   1944-04-19
# 20839   2022-01-19
# 25028   2017-11-16
# 25103          NaN
# 33784   2023-02-04
# 33835          NaN
# 34184          NaN
# 44397   1990-07-07
# 46985   1982-02-02
# 54331          NaN
# 56592   2016-04-24
# 60189   2008-03-18
# 65767   1957-03-29
# 68445   1960-11-02
# 68574   1975-03-29
# 68590   1945-12-18
# 68591   1965-09-04
# 77943          NaN
# 84127   1969-02-14
# 89821          NaN
# 93106          NaN
# 94749          NaN
# 94933          NaN
# 96180   2021-02-19
# 96329          NaN
# 96357          NaN
# 96808          NaN
# 97304          NaN
# 99906          NaN
# 100267         NaN
# 100585         NaN
# 117035         NaN
# 117534         NaN
# 123997         NaN
# 139669         NaN
# 143141         NaN
# 143828         NaN

# %%
bios.query('born_country == "USA"')
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# 960      California          USA         Mexico      170.0       60.0
# 961      California          USA         Mexico      160.0       54.0
# 1231           Ohio          USA         Canada        NaN        NaN
# 1345     California          USA  United States      168.0       61.0
# ...             ...          ...            ...        ...        ...
# 145445  Connecticut          USA  United States        NaN        NaN
# 145446   Washington          USA  United States        NaN        NaN
# 145454    Wisconsin          USA  United States        NaN        NaN
# 145457   California          USA  United States        NaN        NaN
# 145468     Michigan          USA  United States      187.0       97.0
#
#          died_date
# 54             NaN
# 960            NaN
# 961            NaN
# 1231    1986-02-20
# 1345           NaN
# ...            ...
# 145445         NaN
# 145446         NaN
# 145454         NaN
# 145457         NaN
# 145468         NaN
#
# [9641 rows x 10 columns]

# %%
bios.query('born_country == "USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 11030           USA  United States      178.0       79.0         NaN
# 12800           USA  United States      180.0       75.0         NaN
# 15476           USA  United States      183.0       75.0         NaN
# 29079           USA  United States      156.0       49.0         NaN
# 31135           USA  United States        NaN        NaN  2001-07-08
# ...             ...            ...        ...        ...         ...
# 133392          USA  United States      188.0       91.0         NaN
# 135448          USA       Colombia        NaN        NaN         NaN
# 136993          USA  United States        NaN        NaN         NaN
# 143507          USA  United States      175.0       73.0         NaN
# 145446          USA  United States        NaN        NaN         NaN
#
# [102 rows x 10 columns]

# %% [markdown]
# ## Adding / Removing Columns

# %%
coffee['price'] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          10   4.99
# 2    Tuesday    Espresso          10   4.99
# 3    Tuesday       Latte          10   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
coffee['new_price'] = np.where(coffee["Coffee Type"]=="Espresso",3.99, 5.99)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          10   4.99       3.99
# 3     Tuesday       Latte          10   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          10   4.99       3.99
# 3     Tuesday       Latte          10   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(columns=['price'])
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          10       5.99
# 2     Tuesday    Espresso          10       3.99
# 3     Tuesday       Latte          10       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee["revenu"] = coffee["Units Sold"] * coffee["new_price"]
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  new_price  revenu
# 0     Monday    Espresso          25   4.99       3.99   99.75
# 1     Monday       Latte          10   4.99       5.99   59.90
# 2    Tuesday    Espresso          10   4.99       3.99   39.90
# 3    Tuesday       Latte          10   4.99       5.99   59.90
# 4  Wednesday    Espresso          35   4.99       3.99  139.65

# %%
coffee = coffee.drop(columns=['price'],axis=0)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu
# 0      Monday    Espresso          25       3.99   99.75
# 1      Monday       Latte          10       5.99   59.90
# 2     Tuesday    Espresso          10       3.99   39.90
# 3     Tuesday       Latte          10       5.99   59.90
# 4   Wednesday    Espresso          35       3.99  139.65
# 5   Wednesday       Latte          25       5.99  149.75
# 6    Thursday    Espresso          40       3.99  159.60
# 7    Thursday       Latte          30       5.99  179.70
# 8      Friday    Espresso          45       3.99  179.55
# 9      Friday       Latte          35       5.99  209.65
# 10   Saturday    Espresso          45       3.99  179.55
# 11   Saturday       Latte          35       5.99  209.65
# 12     Sunday    Espresso          45       3.99  179.55
# 13     Sunday       Latte          35       5.99  209.65

# %%
coffee.rename(columns={'new_price':'price'})
# Out:
#           Day Coffee Type  Units Sold  price  revenu
# 0      Monday    Espresso          25   3.99   99.75
# 1      Monday       Latte          10   5.99   59.90
# 2     Tuesday    Espresso          10   3.99   39.90
# 3     Tuesday       Latte          10   5.99   59.90
# 4   Wednesday    Espresso          35   3.99  139.65
# 5   Wednesday       Latte          25   5.99  149.75
# 6    Thursday    Espresso          40   3.99  159.60
# 7    Thursday       Latte          30   5.99  179.70
# 8      Friday    Espresso          45   3.99  179.55
# 9      Friday       Latte          35   5.99  209.65
# 10   Saturday    Espresso          45   3.99  179.55
# 11   Saturday       Latte          35   5.99  209.65
# 12     Sunday    Espresso          45   3.99  179.55
# 13     Sunday       Latte          35   5.99  209.65

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.query('first_name == "David"')
# Out:
#         athlete_id              name   born_date        born_city  \
# 153            154    David Prinosil  1973-03-09          Olomouc
# 296            297       David Anear  1948-03-26        Lowestoft
# 585            587        David Pink  1939-12-31  Southend-on-Sea
# 747            751      David Humble  1967-03-06         Dumfries
# 1151          1158   David Defiagbon  1970-06-12           Sapele
# ...            ...               ...         ...              ...
# 144173      147851      David Komatz  1991-12-10       Rottenmann
# 144286      147973  David Desharnais  1986-09-14  Laurier-Station
# 144496      148188       David Musil  1993-04-09          Calgary
# 144498      148190   David Sklenička  1996-09-08         Rakovnik
# 145422      149145   David Warsofsky  1990-05-30       Marshfield
#
#              born_region born_country             NOC  height_cm  weight_kg  \
# 153       Olomoucký kraj          CZE         Germany      184.0       79.0
# 296              England          GBR       Australia      175.0       80.0
# 585              England          GBR   Great Britain      185.0       68.0
# 747             Scotland          GBR          Canada      183.0       76.0
# 1151               Delta          NGR  Canada Nigeria      195.0       91.0
# ...                  ...          ...             ...        ...        ...
# 144173        Steiermark          AUT         Austria        NaN        NaN
# 144286            Québec          CAN          Canada      175.0        NaN
# 144496           Alberta          CAN         Czechia      193.0        NaN
# 144498  Středočeský kraj          CZE         Czechia      183.0        NaN
# 145422     Massachusetts          USA   United States        NaN        NaN
#
#          died_date first_name
# 153            NaN      David
# 296            NaN      David
# 585            NaN      David
# 747            NaN      David
# 1151    2018-11-24      David
# ...            ...        ...
# 144173         NaN      David
# 144286         NaN      David
# 144496         NaN      David
# 144498         NaN      David
# 145422         NaN      David
#
# [593 rows x 11 columns]

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name born_datetime
# 0       1960-10-02  Jean-François    1886-12-12
# 1              NaN         Arnaud    1969-04-01
# 2       1994-07-17           Jean    1898-08-13
# 3       1978-03-20        Jacques    1895-05-11
# 4       1930-07-25         Albert    1878-04-17
# ...            ...            ...           ...
# 145495         NaN         Polina    2002-01-30
# 145496         NaN       Valeriya    1999-09-20
# 145497         NaN         Yuliya    1998-05-08
# 145498  1986-03-18          André    1899-05-19
# 145499  2003-10-20           Bill    1913-07-15
#
# [145500 rows x 12 columns]

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'], errors="coerce")

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'], format="%Y-%m-%d")

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name born_datetime  born_year
# 0       1960-10-02  Jean-François    1886-12-12     1886.0
# 1              NaN         Arnaud    1969-04-01     1969.0
# 2       1994-07-17           Jean    1898-08-13     1898.0
# 3       1978-03-20        Jacques    1895-05-11     1895.0
# 4       1930-07-25         Albert    1878-04-17     1878.0
# ...            ...            ...           ...        ...
# 145495         NaN         Polina    2002-01-30     2002.0
# 145496         NaN       Valeriya    1999-09-20     1999.0
# 145497         NaN         Yuliya    1998-05-08     1998.0
# 145498  1986-03-18          André    1899-05-19     1899.0
# 145499  2003-10-20           Bill    1913-07-15     1913.0
#
# [145500 rows x 13 columns]

# %%
# reference - https://datapythonista.me/blog/pandas-20-and-the-arrow-revolution-part-i
# https://strftime.org/

# %%
bios_new.to_csv('data/bios_new.csv',index=False)

# %%
bios['height_catagory'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Avg' if x < 185 else "Tall"))

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_catagory
# 0  1960-10-02            Tall
# 1         NaN             Avg
# 2  1994-07-17             Avg
# 3  1978-03-20             Avg
# 4  1930-07-25            Tall

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Leight Weight'
    elif row['height_cm'] < 185 or row["weight_kg"] <= 80:
        return 'Middle Weight'
    else:
        return "Heavy Weight"
    
bios['Category'] = bios.apply(categorize_athlete, axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_catagory       Category
# 0  1960-10-02            Tall   Heavy Weight
# 1         NaN             Avg  Middle Weight
# 2  1994-07-17             Avg  Middle Weight
# 3  1978-03-20             Avg  Leight Weight
# 4  1930-07-25            Tall   Heavy Weight

# %% [markdown]
# ## Merging & Concatenating Data

# %%
nocs = pd.read_csv('data/noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
born_new = pd.merge(bios,nocs, left_on='born_country', right_on='NOC' , how='left')

# %%
born_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_catagory       Category NOC_y  region notes
# 0  1960-10-02            Tall   Heavy Weight   FRA  France   NaN
# 1         NaN             Avg  Middle Weight   FRA  France   NaN
# 2  1994-07-17             Avg  Middle Weight   FRA  France   NaN
# 3  1978-03-20             Avg  Leight Weight   FRA  France   NaN
# 4  1930-07-25            Tall   Heavy Weight   GBR      UK   NaN

# %%
born_new.rename(columns={'region':'born_country_full'},inplace=True)

# %%
born_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_catagory       Category NOC_y born_country_full notes
# 0  1960-10-02            Tall   Heavy Weight   FRA            France   NaN
# 1         NaN             Avg  Middle Weight   FRA            France   NaN
# 2  1994-07-17             Avg  Middle Weight   FRA            France   NaN
# 3  1978-03-20             Avg  Leight Weight   FRA            France   NaN
# 4  1930-07-25            Tall   Heavy Weight   GBR                UK   NaN

# %%
born_new[born_new['NOC_x'] != born_new['born_country_full']][['name','NOC_x','born_country_full']]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR'].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_catagory       Category
# 54               Avg  Middle Weight
# 960              Avg  Leight Weight
# 961            Short  Leight Weight
# 1231            Tall   Heavy Weight
# 1345             Avg  Leight Weight

# %%
usa.tail()
# Out:
#         athlete_id               name   born_date      born_city  born_region  \
# 145445      149168     Kristen Santos  1994-11-02      Fairfield  Connecticut
# 145446      149169   Corinne Stoddard  2001-08-15        Seattle   Washington
# 145454      149180      Anna Hoffmann  2000-03-28        Madison    Wisconsin
# 145457      149183     Alix Wilkinson  2000-08-02  Mammoth Lakes   California
# 145468      149195  Justin Abdelkader  1987-02-25       Muskegon     Michigan
#
#        born_country            NOC  height_cm  weight_kg died_date  \
# 145445          USA  United States        NaN        NaN       NaN
# 145446          USA  United States        NaN        NaN       NaN
# 145454          USA  United States        NaN        NaN       NaN
# 145457          USA  United States        NaN        NaN       NaN
# 145468          USA  United States      187.0       97.0       NaN
#
#        height_catagory      Category
# 145445            Tall  Heavy Weight
# 145446            Tall  Heavy Weight
# 145454            Tall  Heavy Weight
# 145457            Tall  Heavy Weight
# 145468            Tall  Heavy Weight

# %%
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date  \
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN
#
#    height_catagory       Category
# 4             Tall   Heavy Weight
# 37            Tall   Heavy Weight
# 38            Tall   Heavy Weight
# 39            Tall   Heavy Weight
# 40             Avg  Middle Weight

# %%
new_df = pd.concat([usa,gbr])

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_catagory       Category
# 54               Avg  Middle Weight
# 960              Avg  Leight Weight
# 961            Short  Leight Weight
# 1231            Tall   Heavy Weight
# 1345             Avg  Leight Weight

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_catagory       Category
# 144811            Tall   Heavy Weight
# 144815            Tall   Heavy Weight
# 145005             Avg  Middle Weight
# 145319            Tall   Heavy Weight
# 145388            Tall   Heavy Weight

# %%
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
combined_df = pd.merge(result,bios, on='athlete_id',how='left')

# %%
combined_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied  ...   born_date born_city  \
# 0           1  FRA             None   17.0   True  ...  1886-12-12  Bordeaux
# 1           1  FRA   Jean Montariol    NaN  False  ...  1886-12-12  Bordeaux
# 2           1  FRA             None   32.0   True  ...  1886-12-12  Bordeaux
# 3           1  FRA  Jeanne Vaussard    8.0   True  ...  1886-12-12  Bordeaux
# 4           1  FRA  Jacques Brugnon    4.0  False  ...  1886-12-12  Bordeaux
#
#   born_region born_country     NOC height_cm weight_kg   died_date  \
# 0     Gironde          FRA  France       NaN       NaN  1960-10-02
# 1     Gironde          FRA  France       NaN       NaN  1960-10-02
# 2     Gironde          FRA  France       NaN       NaN  1960-10-02
# 3     Gironde          FRA  France       NaN       NaN  1960-10-02
# 4     Gironde          FRA  France       NaN       NaN  1960-10-02
#
#    height_catagory      Category
# 0             Tall  Heavy Weight
# 1             Tall  Heavy Weight
# 2             Tall  Heavy Weight
# 3             Tall  Heavy Weight
# 4             Tall  Heavy Weight
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Handling Null Values

# %%
coffee.loc[[0,1], 'Units Sold'] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu
# 0      Monday    Espresso         NaN       3.99   99.75
# 1      Monday       Latte         NaN       5.99   59.90
# 2     Tuesday    Espresso        10.0       3.99   39.90
# 3     Tuesday       Latte        10.0       5.99   59.90
# 4   Wednesday    Espresso        35.0       3.99  139.65
# 5   Wednesday       Latte        25.0       5.99  149.75
# 6    Thursday    Espresso        40.0       3.99  159.60
# 7    Thursday       Latte        30.0       5.99  179.70
# 8      Friday    Espresso        45.0       3.99  179.55
# 9      Friday       Latte        35.0       5.99  209.65
# 10   Saturday    Espresso        45.0       3.99  179.55
# 11   Saturday       Latte        35.0       5.99  209.65
# 12     Sunday    Espresso        45.0       3.99  179.55
# 13     Sunday       Latte        35.0       5.99  209.65

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   12 non-null     float64
#  3   new_price    14 non-null     float64
#  4   revenu       14 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 692.0+ bytes

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# new_price      0
# revenu         0
# dtype: int64

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu
# 0      Monday    Espresso        32.5       3.99   99.75
# 1      Monday       Latte        32.5       5.99   59.90
# 2     Tuesday    Espresso        10.0       3.99   39.90
# 3     Tuesday       Latte        10.0       5.99   59.90
# 4   Wednesday    Espresso        35.0       3.99  139.65
# 5   Wednesday       Latte        25.0       5.99  149.75
# 6    Thursday    Espresso        40.0       3.99  159.60
# 7    Thursday       Latte        30.0       5.99  179.70
# 8      Friday    Espresso        45.0       3.99  179.55
# 9      Friday       Latte        35.0       5.99  209.65
# 10   Saturday    Espresso        45.0       3.99  179.55
# 11   Saturday       Latte        35.0       5.99  209.65
# 12     Sunday    Espresso        45.0       3.99  179.55
# 13     Sunday       Latte        35.0       5.99  209.65

# %%
coffee.loc[[2,3], 'Units Sold'] = np.nan

# %%
coffee.loc[[0,1],'Units Sold'] = 15

# %%
coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu
# 0      Monday    Espresso   15.000000       3.99   99.75
# 1      Monday       Latte   15.000000       5.99   59.90
# 2     Tuesday    Espresso   21.666667       3.99   39.90
# 3     Tuesday       Latte   28.333333       5.99   59.90
# 4   Wednesday    Espresso   35.000000       3.99  139.65
# 5   Wednesday       Latte   25.000000       5.99  149.75
# 6    Thursday    Espresso   40.000000       3.99  159.60
# 7    Thursday       Latte   30.000000       5.99  179.70
# 8      Friday    Espresso   45.000000       3.99  179.55
# 9      Friday       Latte   35.000000       5.99  209.65
# 10   Saturday    Espresso   45.000000       3.99  179.55
# 11   Saturday       Latte   35.000000       5.99  209.65
# 12     Sunday    Espresso   45.000000       3.99  179.55
# 13     Sunday       Latte   35.000000       5.99  209.65

# %%
coffee.dropna(subset=['Units Sold'], inplace=True)

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
# Empty DataFrame
# Columns: [Day, Coffee Type, Units Sold, new_price, revenu]
# Index: []

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu
# 0      Monday    Espresso   15.000000       3.99   99.75
# 1      Monday       Latte   15.000000       5.99   59.90
# 2     Tuesday    Espresso   21.666667       3.99   39.90
# 3     Tuesday       Latte   28.333333       5.99   59.90
# 4   Wednesday    Espresso   35.000000       3.99  139.65
# 5   Wednesday       Latte   25.000000       5.99  149.75
# 6    Thursday    Espresso   40.000000       3.99  159.60
# 7    Thursday       Latte   30.000000       5.99  179.70
# 8      Friday    Espresso   45.000000       3.99  179.55
# 9      Friday       Latte   35.000000       5.99  209.65
# 10   Saturday    Espresso   45.000000       3.99  179.55
# 11   Saturday       Latte   35.000000       5.99  209.65
# 12     Sunday    Espresso   45.000000       3.99  179.55
# 13     Sunday       Latte   35.000000       5.99  209.65

# %% [markdown]
# ## Aggregating Data

# %%
bios.value_counts()
# Out:
# athlete_id  name               born_date   born_city    born_region           born_country  NOC            height_cm  weight_kg  died_date   height_catagory  Category
# 144729      Naonobu Fujii      1992-01-05  Ishinomaki   Miyagi                JPN           Japan          183.0      80.0       2023-03-10  Avg              Middle Weight    1
# 3           Jean Borotra       1898-08-13  Biarritz     Pyrénées-Atlantiques  FRA           France         183.0      76.0       1994-07-17  Avg              Middle Weight    1
# 4           Jacques Brugnon    1895-05-11  Paris VIIIe  Paris                 FRA           France         168.0      64.0       1978-03-20  Avg              Leight Weight    1
# 108         Anders Nielsen     1967-02-24  Cape Town    Western Cape          RSA           Great Britain  173.0      70.0       2010-07-29  Avg              Middle Weight    1
# 259         Tonny Maringgi     1959-06-10  Kendari      Sulawesi Tenggara     INA           Indonesia      167.0      65.0       2019-09-15  Avg              Leight Weight    1
#                                                                                                                                                                               ..
# 595         Simon Terry        1974-02-27  Stirling     Scotland              GBR           Great Britain  180.0      100.0      2021-07-19  Avg              Middle Weight    1
# 525         Rudi Schiffl       1941-08-18  Dachau       Bayern                GER           West Germany   185.0      77.0       2013-03-08  Tall             Middle Weight    1
# 445         Markku Syrjälä     1955-05-12  Kurikka      Etelä-Pohjanmaa       FIN           Finland        186.0      65.0       2023-10-11  Tall             Middle Weight    1
# 434         Carita Jussila     1947-08-20  Helsinki     Uusimaa               FIN           Finland        164.0      59.0       2011-03-18  Short            Leight Weight    1
# 427         Francisco Peralta  1943-09-18  Manzanilla   Huelva                ESP           Spain          176.0      63.0       2020-03-18  Avg              Middle Weight    1
# Name: count, Length: 10794, dtype: int64

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Kirovgrad             1
# Pereiaslav            1
# Podgornyy             1
# Kudepsta              1
# Furmanov              1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Massachusetts            530
# Pennsylvania             530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# Vermont                   68
# Mississippi               66
# Alabama                   64
# Kentucky                  62
# Tennessee                 62
# Nebraska                  60
# Rhode Island              56
# Montana                   55
# Maine                     50
# South Carolina            50
# Alaska                    45
# Arkansas                  42
# Idaho                     41
# New Mexico                38
# Nevada                    36
# South Dakota              27
# West Virginia             24
# Delaware                  22
# North Dakota              16
# Wyoming                   14
# Name: count, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts().tail()
# Out:
# born_region
# South Dakota     27
# West Virginia    24
# Delaware         22
# North Dakota     16
# Wyoming          14
# Name: count, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    246.666667
# Latte       203.333333
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    35.238095
# Latte       29.047619
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold':'sum','new_price':'mean'})
# Out:
#              Units Sold  new_price
# Coffee Type
# Espresso     246.666667       3.99
# Latte        203.333333       5.99

# %%
coffee.groupby(['Coffee Type','Day']).agg({'Units Sold':'sum','new_price':'mean'})
# Out:
#                        Units Sold  new_price
# Coffee Type Day
# Espresso    Friday      45.000000       3.99
#             Monday      15.000000       3.99
#             Saturday    45.000000       3.99
#             Sunday      45.000000       3.99
#             Thursday    40.000000       3.99
#             Tuesday     21.666667       3.99
#             Wednesday   35.000000       3.99
# Latte       Friday      35.000000       5.99
#             Monday      15.000000       5.99
#             Saturday    35.000000       5.99
#             Sunday      35.000000       5.99
#             Thursday    30.000000       5.99
#             Tuesday     28.333333       5.99
#             Wednesday   25.000000       5.99

# %%
pivot = coffee.pivot(columns="Coffee Type", index="Day", values="revenu")

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   59.90
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday         39.90   59.90
# Wednesday      139.65  149.75

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso     977.55
# Latte       1078.20
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.20
# Monday       159.65
# Saturday     389.20
# Sunday       389.20
# Thursday     339.30
# Tuesday       99.80
# Wednesday    289.40
# dtype: float64

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 4       1837.0     1
# 2       1833.0     1
# 6       1839.0     1
# 12      1845.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])
bios['month_born'] = bios['born_date'].dt.month
bios['year_born'] = bios['born_date'].dt.year
bios.groupby([bios['year_born'],bios['month_born']])['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1497     1975.0         1.0   227
# 1629     1986.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 1877     2006.0        12.0     1
# 1871     2006.0         3.0     1
# 20       1846.0         7.0     1
# 21       1846.0         8.0     1
# 22       1846.0         9.0     1
#
# [1885 rows x 3 columns]

# %% [markdown]
# ## Advanced Functionality

# %%
# shift() rank() cumsum() rolling()

# %%
coffee['yesterday_revenu'] = coffee['revenu'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu  yesterday_revenu
# 0      Monday    Espresso   15.000000       3.99   99.75               NaN
# 1      Monday       Latte   15.000000       5.99   59.90               NaN
# 2     Tuesday    Espresso   21.666667       3.99   39.90             99.75
# 3     Tuesday       Latte   28.333333       5.99   59.90             59.90
# 4   Wednesday    Espresso   35.000000       3.99  139.65             39.90
# 5   Wednesday       Latte   25.000000       5.99  149.75             59.90
# 6    Thursday    Espresso   40.000000       3.99  159.60            139.65
# 7    Thursday       Latte   30.000000       5.99  179.70            149.75
# 8      Friday    Espresso   45.000000       3.99  179.55            159.60
# 9      Friday       Latte   35.000000       5.99  209.65            179.70
# 10   Saturday    Espresso   45.000000       3.99  179.55            179.55
# 11   Saturday       Latte   35.000000       5.99  209.65            209.65
# 12     Sunday    Espresso   45.000000       3.99  179.55            179.55
# 13     Sunday       Latte   35.000000       5.99  209.65            209.65

# %%
coffee['precentage_change'] = coffee['revenu'] / coffee['yesterday_revenu'] * 100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu  yesterday_revenu  \
# 0      Monday    Espresso   15.000000       3.99   99.75               NaN
# 1      Monday       Latte   15.000000       5.99   59.90               NaN
# 2     Tuesday    Espresso   21.666667       3.99   39.90             99.75
# 3     Tuesday       Latte   28.333333       5.99   59.90             59.90
# 4   Wednesday    Espresso   35.000000       3.99  139.65             39.90
# 5   Wednesday       Latte   25.000000       5.99  149.75             59.90
# 6    Thursday    Espresso   40.000000       3.99  159.60            139.65
# 7    Thursday       Latte   30.000000       5.99  179.70            149.75
# 8      Friday    Espresso   45.000000       3.99  179.55            159.60
# 9      Friday       Latte   35.000000       5.99  209.65            179.70
# 10   Saturday    Espresso   45.000000       3.99  179.55            179.55
# 11   Saturday       Latte   35.000000       5.99  209.65            209.65
# 12     Sunday    Espresso   45.000000       3.99  179.55            179.55
# 13     Sunday       Latte   35.000000       5.99  209.65            209.65
#
#     precentage_change
# 0                 NaN
# 1                 NaN
# 2           40.000000
# 3          100.000000
# 4          350.000000
# 5          250.000000
# 6          114.285714
# 7          120.000000
# 8          112.500000
# 9          116.666667
# 10         100.000000
# 11         100.000000
# 12         100.000000
# 13         100.000000

# %%
bios['height_rank'] = bios['height_cm'].rank(ascending=False)

# %%
bios.sort_values(['height_rank']).sample(10)[['name','height_rank']]
# Out:
#                           name  height_rank
# 25195             Hermann Bitz      77037.5
# 84998               Ion Ferenz      94490.0
# 121996             Andrés Mata      62600.5
# 118815    Antonina Krivoshapka      83975.0
# 142043               Ekpe Udoh        261.0
# 82341             Wang Guifang          NaN
# 92978            Raluca Udroiu      46966.0
# 73150    Berny Boxem-Lenferink      69980.5
# 138168  Félix Auger-Aliassime          NaN
# 63559           Juan Villareal          NaN

# %%
coffee['cumulative_revenue'] = coffee['revenu'].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu  yesterday_revenu  \
# 0      Monday    Espresso   15.000000       3.99   99.75               NaN
# 1      Monday       Latte   15.000000       5.99   59.90               NaN
# 2     Tuesday    Espresso   21.666667       3.99   39.90             99.75
# 3     Tuesday       Latte   28.333333       5.99   59.90             59.90
# 4   Wednesday    Espresso   35.000000       3.99  139.65             39.90
# 5   Wednesday       Latte   25.000000       5.99  149.75             59.90
# 6    Thursday    Espresso   40.000000       3.99  159.60            139.65
# 7    Thursday       Latte   30.000000       5.99  179.70            149.75
# 8      Friday    Espresso   45.000000       3.99  179.55            159.60
# 9      Friday       Latte   35.000000       5.99  209.65            179.70
# 10   Saturday    Espresso   45.000000       3.99  179.55            179.55
# 11   Saturday       Latte   35.000000       5.99  209.65            209.65
# 12     Sunday    Espresso   45.000000       3.99  179.55            179.55
# 13     Sunday       Latte   35.000000       5.99  209.65            209.65
#
#     precentage_change  cumulative_revenue
# 0                 NaN               99.75
# 1                 NaN              159.65
# 2           40.000000              199.55
# 3          100.000000              259.45
# 4          350.000000              399.10
# 5          250.000000              548.85
# 6          114.285714              708.45
# 7          120.000000              888.15
# 8          112.500000             1067.70
# 9          116.666667             1277.35
# 10         100.000000             1456.90
# 11         100.000000             1666.55
# 12         100.000000             1846.10
# 13         100.000000             2055.75

# %%
latte = coffee[coffee['Coffee Type'] == "Latte"].copy()
latte['3day'] = latte['Units Sold'].rolling(3).sum()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold  new_price  revenu  yesterday_revenu  \
# 1      Monday       Latte   15.000000       5.99   59.90               NaN
# 3     Tuesday       Latte   28.333333       5.99   59.90             59.90
# 5   Wednesday       Latte   25.000000       5.99  149.75             59.90
# 7    Thursday       Latte   30.000000       5.99  179.70            149.75
# 9      Friday       Latte   35.000000       5.99  209.65            179.70
# 11   Saturday       Latte   35.000000       5.99  209.65            209.65
# 13     Sunday       Latte   35.000000       5.99  209.65            209.65
#
#     precentage_change  cumulative_revenue        3day
# 1                 NaN              159.65         NaN
# 3          100.000000              259.45         NaN
# 5          250.000000              548.85   68.333333
# 7          120.000000              888.15   83.333333
# 9          116.666667             1277.35   90.000000
# 11         100.000000             1666.55  100.000000
# 13         100.000000             2055.75  105.000000

# %% [markdown]
# ## Advanced Functionality (cont.)

# %%
result_numpy = pd.read_csv('data/results.csv')
result_arrow = pd.read_csv('data/results.csv', engine="pyarrow" , dtype_backend="pyarrow")

# %%
result_numpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
result_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB

# %%
filtered_bios = bios[(bios['born_region'] == 'New Hampshire') | (bios['born_city'] == 'San Francisco')]

bios.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_catagory       Category  month_born  year_born  \
# 0  1960-10-02            Tall   Heavy Weight        12.0     1886.0
# 1         NaN             Avg  Middle Weight         4.0     1969.0
# 2  1994-07-17             Avg  Middle Weight         8.0     1898.0
# 3  1978-03-20             Avg  Leight Weight         5.0     1895.0
# 4  1930-07-25            Tall   Heavy Weight         4.0     1878.0
#
#    height_rank
# 0          NaN
# 1      27597.5
# 2      27597.5
# 3      83975.0
# 4          NaN

# %%
import pandas as pd

# Creating a DataFrame
data = {
    'Date': ['2024-05-01', '2024-05-01', '2024-05-01', '2024-05-02', '2024-05-02', '2024-05-03', '2024-05-03', '2024-05-03'],
    'Item': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Orange'],
    'Units Sold': [30, 21, 15, 40, 34, 20, 45, 25],
    'Price Per Unit': [1.0, 0.5, 0.75, 1.0, 0.5, 0.75, 1.0, 0.75],
    'Salesperson': ['John', 'John', 'John', 'Alice', 'Alice', 'John', 'Alice', 'John']
}

df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#          Date    Item  Units Sold  Price Per Unit Salesperson
# 0  2024-05-01   Apple          30            1.00        John
# 1  2024-05-01  Banana          21            0.50        John
# 2  2024-05-01  Orange          15            0.75        John
# 3  2024-05-02   Apple          40            1.00       Alice
# 4  2024-05-02  Banana          34            0.50       Alice
# 5  2024-05-03  Orange          20            0.75        John
# 6  2024-05-03   Apple          45            1.00       Alice
# 7  2024-05-03  Orange          25            0.75        John

# %%
pivot_table = pd.pivot_table(df, values='Units Sold', index='Date', columns='Item', aggfunc='sum')
pivot_table
# Out:
# Item        Apple  Banana  Orange
# Date
# 2024-05-01   30.0    21.0    15.0
# 2024-05-02   40.0    34.0     NaN
# 2024-05-03   45.0     NaN    45.0

# %%
! pip3 install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp311-cp311-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/munusami/Desktop/M.Tech AI program/Python/.venv/lib/python3.11/site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/munusami/Desktop/M.Tech AI program/Python/.venv/lib/python3.11/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp311-cp311-macosx_10_10_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/munusami/Desktop/M.Tech AI program/Python/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/munusami/Desktop/M.Tech AI program/Python/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp311-cp311-macosx_10_12_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 5.9 MB/s eta 0:00:0000:0100:01
# Using cached contourpy-1.2.1-cp311-cp311-macosx_10_9_x86_64.whl (262 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.6 MB/s eta 0:00:0000:0100:01
# Using cached kiwisolver-1.4.5-cp311-cp311-macosx_10_9_x86_64.whl (68 kB)
# Downloading pillow-10.4.0-cp311-cp311-macosx_10_10_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 7.4 MB/s eta 0:00:0000:0100:01
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'bios' and already loaded
# First, filter out rows where the height_cm data is missing
bios_filtered = bios.dropna(subset=['height_cm'])

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(bios_filtered['height_cm'], bins=20, color='blue', edgecolor='black')

plt.title('Distribution of Athlete Heights in Olympics')
plt.xlabel('Height in cm')
plt.ylabel('Number of Athletes')
plt.grid(True)

# Using a logarithmic scale for the y-axis if the data spread is wide
plt.yscale('log')

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# #####  *Author - Muralidharan Venkadesan*
#
# ##### *LinkedIn profile - https://www.linkedin.com/in/muralidharanvenkadesan/*
