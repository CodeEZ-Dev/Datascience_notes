# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pltx
import scipy.stats as st
import statsmodels.stats as sm

# %%
n=3
p=0.5
x=np.arange(0,4)

# %%
x
# Out:
# array([0, 1, 2, 3])

# %%
# p(x=2)
st.binom.pmf(2,n,p)
# Out:
# np.float64(0.3750000000000001)

# %%
3/8
# Out:
# 0.375

# %%
p =st.binom.pmf(x,n,p)

# %%
sns.barplot(x=x,y=p, palette="tab10")
# Out:
# /var/folders/qj/948gfl_s7ps7l_t1pwg1clpc0000gn/T/ipykernel_42392/2260177746.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=p, palette="tab10")
# <Axes: >

# %%
n=3
p=0.5
c =st.binom.sf(x-1,n,p)
c
# Out:
# array([1.   , 0.875, 0.5  , 0.125])

# %%
sns.barplot(x=x,y=c,palette="tab10")
# Out:
# /var/folders/qj/948gfl_s7ps7l_t1pwg1clpc0000gn/T/ipykernel_42392/344301335.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=c,palette="tab10")
# <Axes: >

# %%
n=50
p=11/15
x=35

# %%
bd = st.binom.pmf(x,n,p)
bd
# Out:
# np.float64(0.10651812440300873)

# %%
cdf = st.binom.cdf(35,n,p)
cdf
# Out:
# np.float64(0.3467583295298203)

# %%
sf = st.binom.sf(35,n,p)
res = 1-sf
res
# Out:
# np.float64(0.3467583295298202)

# %%
res = cdf+st.binom.sf(34,n,p)-st.binom.pmf(35,n,p)
res
# Out:
# np.float64(1.0000000000000002)

# %%
st.binom.cdf(50,50,11/15)
# Out:
# np.float64(1.0)

# %%
x=np.arange(0,51)

# %%
cf = st.binom.cdf(x,50,11/15)
cf
# Out:
# array([1.98809262e-29, 2.75350828e-27, 1.86931651e-25, 8.29076995e-24,
#        2.70146045e-22, 6.89508450e-21, 1.43534440e-19, 2.50544330e-18,
#        3.74174087e-17, 4.85454297e-16, 5.53707022e-15, 5.60532294e-14,
#        5.07541402e-13, 4.13681172e-12, 3.05138299e-11, 2.04602150e-10,
#        1.25185220e-09, 7.01172747e-09, 3.60510986e-08, 1.70549239e-07,
#        7.43847561e-07, 2.99609097e-06, 1.11604733e-05, 3.84934056e-05,
#        1.23054665e-04, 3.64899866e-04, 1.00439439e-03, 2.56760322e-03,
#        6.09878031e-03, 1.34655463e-02, 2.76465709e-02, 5.28064532e-02,
#        9.38878235e-02, 1.55509879e-01, 2.40240205e-01, 3.46758330e-01,
#        4.68810347e-01, 5.95810419e-01, 7.15290751e-01, 8.16389492e-01,
#        8.92845416e-01, 9.44126828e-01, 9.74346231e-01, 9.89807322e-01,
#        9.96571549e-01, 9.99051765e-01, 9.99793134e-01, 9.99966646e-01,
#        9.99996468e-01, 9.99999816e-01, 1.00000000e+00])

# %%
plt.figure(figsize=(20,15))
sns.barplot(x=x,y=cf)
# Out:
# <Axes: >

# %%
# passion distubtion
lamda = 15 
# p(x=20)

res = st.poisson.pmf(20,lamda)
res
# Out:
# np.float64(0.04181030500106466)

# %%
# p(x>=20)

res = st.poisson.cdf(19,lamda)
f_res = 1-res
f_res
# Out:
# np.float64(0.12478121503252493)

# %%
res =  st.poisson.sf(19,lamda)
res
# Out:
# np.float64(0.12478121503252496)

# %%
res =  st.poisson.cdf(20,lamda)
res
# Out:
# np.float64(0.9170290899685397)

# %%
x=513.5
mu=500
sigma = 10 


z=(x-mu)/sigma
z
# Out:
# 1.35

# %%
st.norm.sf(z)
# Out:
# np.float64(0.08850799143740196)

# %% [markdown]
# The systolic pressure of a randomly selected people of group is normaly distributed with mean value of 118psi and standarad deviation of 15 psi.
# What is the probability of randomly selected person is
# a) between 120 and 139 psi
# b) less than 120 psi
# c) greater than 140psi

# %%
mu = 118
s= 15 
x1 =129
x2 = 139 
#less than 120 psi
res2 = st.norm.cdf(120,118,15)
res2
# Out:
# np.float64(0.553035116623614)

# %%
#between 120 and 139 psi
res1 =st.norm.cdf(139,118,15)-st.norm.cdf(120,118,15)
res1
# Out:
# np.float64(0.3662082241426149)

# %%
#greater than 140psi

res3 = st.norm.cdf(140,118,15)
f_res = 1-res3
f_res
# Out:
# np.float64(0.07123337741398617)
